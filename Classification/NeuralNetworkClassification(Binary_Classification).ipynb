# %%
import matplotlib
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_circles
import sklearn

# %%
print ("tensorflow version: ", tf.__version__)
print ("numpy version: ", np.__version__)
print ("pandas version: ", pd.__version__)
print ("sklearn version: ", sklearn.__version__)
# Out:
# tensorflow version:  2.16.2
# numpy version:  1.26.4
# pandas version:  2.2.2
# sklearn version:  1.5.1

# %%
X,y = make_circles(n_samples=1000, noise=0.05, random_state=42)
X.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(200,activation="relu"),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid'),
])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 10**(epoch/20))
history = model.fit(X, y, epochs=50, verbose=1, callbacks=[lr_scheduler])
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5029 - loss: nan - learning_rate: 1.0000
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5008 - loss: nan - learning_rate: 1.1220
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5059 - loss: nan - learning_rate: 1.2589
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4909 - loss: nan - learning_rate: 1.4125
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5053 - loss: nan - learning_rate: 1.5849
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5125 - loss: nan - learning_rate: 1.7783
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4972 - loss: nan - learning_rate: 1.9953
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5127 - loss: nan - learning_rate: 2.2387
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5097 - loss: nan - learning_rate: 2.5119
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5034 - loss: nan - learning_rate: 2.8184
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5028 - loss: nan - learning_rate: 3.1623
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4965 - loss: nan - learning_rate: 3.5481
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4805 - loss: nan - learning_rate: 3.9811
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4886 - loss: nan - learning_rate: 4.4668
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4837 - loss: nan - learning_rate: 5.0119
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4993 - loss: nan - learning_rate: 5.6234
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5036 - loss: nan - learning_rate: 6.3096
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5031 - loss: nan - learning_rate: 7.0795
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5008 - loss: nan - learning_rate: 7.9433
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5160 - loss: nan - learning_rate: 8.9125
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4995 - loss: nan - learning_rate: 10.0000
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4955 - loss: nan - learning_rate: 11.2202
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4887 - loss: nan - learning_rate: 12.5893
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4883 - loss: nan - learning_rate: 14.1254
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4839 - loss: nan - learning_rate: 15.8489
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4991 - loss: nan - learning_rate: 17.7828
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5003 - loss: nan - learning_rate: 19.9526
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5018 - loss: nan - learning_rate: 22.3872
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5117 - loss: nan - learning_rate: 25.1189
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5017 - loss: nan - learning_rate: 28.1838
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5185 - loss: nan - learning_rate: 31.6228
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5112 - loss: nan - learning_rate: 35.4813
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5053 - loss: nan - learning_rate: 39.8107
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4829 - loss: nan - learning_rate: 44.6684
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4852 - loss: nan - learning_rate: 50.1187
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4883 - loss: nan - learning_rate: 56.2341
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4983 - loss: nan - learning_rate: 63.0957
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4971 - loss: nan - learning_rate: 70.7946
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5116 - loss: nan - learning_rate: 79.4328
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4973 - loss: nan - learning_rate: 89.1251
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5056 - loss: nan - learning_rate: 100.0000
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4837 - loss: nan - learning_rate: 112.2018
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4843 - loss: nan - learning_rate: 125.8925
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5110 - loss: nan - learning_rate: 141.2538
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4965 - loss: nan - learning_rate: 158.4893
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4872 - loss: nan - learning_rate: 177.8279
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4931 - loss: nan - learning_rate: 199.5262
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5195 - loss: nan - learning_rate: 223.8721
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4889 - loss: nan - learning_rate: 251.1886
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4966 - loss: nan - learning_rate: 281.8383

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
model.evaluate(X, y)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9693 - loss: 0.0712
# [0.0745130106806755, 0.9700000286102295]

# %%
def plotDecisionBoundry(model,x,y):
    """plots a decision boundry created by a model"""
    x_min, x_max = x[:, 0].min() - 0.1, x[:, 0].max() + 0.1
    y_min, y_max = x[:, 1].min() - 0.1, x[:, 1].max() + 0.1
    xx,yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                        np.linspace(y_min, y_max, 100))
    x_in = np.c_[xx.ravel(), yy.ravel()]
    z=model.predict(x_in)
    if len(z[0])>1:
        print("multiclass classification")
        z = np.argmax(z,axis=1).reshape(xx.shape)
    else:
        print("binary classification")
        z = np.round(z).reshape(xx.shape)
    plt.contourf(xx,yy,z,cmap=plt.cm.RdYlBu, alpha=0.8)
    plt.scatter(x[:,0],x[:,1],c=y,s=40,cmap=plt.cm.RdYlBu)
    plt.xlim(x_min,x_max)
    plt.ylim(y_min,y_max)

# %%
plotDecisionBoundry(model,X,y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# binary classification
